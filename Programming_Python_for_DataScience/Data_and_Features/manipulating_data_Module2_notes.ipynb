# %%
import pandas as pd

# %%
df = pd.read_csv('direct_market.txt', sep =',')
df.head(7)
# Out:
#    recency history_segment  history  mens  womens   zip_code  newbie channel  \
# 0       10  2) $100 - $200   142.44     1       0  Surburban       0   Phone
# 1        6  3) $200 - $350   329.08     1       1      Rural       1     Web
# 2        7  2) $100 - $200   180.65     0       1  Surburban       1     Web
# 3        9  5) $500 - $750   675.83     1       0      Rural       1     Web
# 4        2    1) $0 - $100    45.34     1       0      Urban       0     Web
# 5        6  2) $100 - $200   134.83     0       1  Surburban       0   Phone
# 6        9  3) $200 - $350   280.20     1       0  Surburban       1   Phone
#
#          segment  visit  conversion  spend  DM_category
# 0  Womens E-Mail      0           0    0.0            4
# 1      No E-Mail      0           0    0.0           11
# 2  Womens E-Mail      0           0    0.0            1
# 3    Mens E-Mail      0           0    0.0            2
# 4  Womens E-Mail      0           0    0.0            4
# ...

# %%
df.recency
# Out:
# 0        10
# 1         6
# 2         7
# 3         9
# 4         2
# 5         6
# 6         9
# 7         9
# 8         9
# 9        10
# 10        7
# 11        1
# 12        5
# 13        2
# 14        4
# 15        3
# 16        5
# 17        9
# 18       11
# 19        5
# 20        9
# 21       11
# 22        2
# 23        2
# 24        4
# 25        6
# 26       12
# 27        6
# 28        7
# 29        2
#          ..
# 63970     4
# 63971     5
# 63972     3
# 63973     8
# 63974     8
# 63975    10
# 63976     1
# 63977     8
# 63978    10
# 63979    10
# 63980     3
# 63981     4
# 63982     5
# 63983     2
# 63984     2
# 63985     9
# 63986     9
# 63987     1
# 63988     6
# 63989    10
# 63990     6
# 63991     1
# 63992     1
# 63993     4
# 63994     7
# 63995    10
# 63996     5
# 63997     6
# 63998     1
# 63999     1
# Name: recency, Length: 64000, dtype: int64

# %%
df.loc[:, 'recency'] # series
df[['recency']] # dataframe
df.iloc[:, [0]] # dataframe
df.iloc[:, 0] # series
# Out:
# 0        10
# 1         6
# 2         7
# 3         9
# 4         2
# 5         6
# 6         9
# 7         9
# 8         9
# 9        10
# 10        7
# 11        1
# 12        5
# 13        2
# 14        4
# 15        3
# 16        5
# 17        9
# 18       11
# 19        5
# 20        9
# 21       11
# 22        2
# 23        2
# 24        4
# 25        6
# 26       12
# 27        6
# 28        7
# 29        2
#          ..
# 63970     4
# 63971     5
# 63972     3
# 63973     8
# 63974     8
# 63975    10
# 63976     1
# 63977     8
# 63978    10
# 63979    10
# 63980     3
# 63981     4
# 63982     5
# 63983     2
# 63984     2
# 63985     9
# 63986     9
# 63987     1
# 63988     6
# 63989    10
# 63990     6
# 63991     1
# 63992     1
# 63993     4
# 63994     7
# 63995    10
# 63996     5
# 63997     6
# 63998     1
# 63999     1
# Name: recency, Length: 64000, dtype: int64

# %%
# [row_indexer, column_indexer]:

df[0:2] # dataframe
df.iloc[0:2, 1] # series
# Out:
# 0    2) $100 - $200
# 1    3) $200 - $350
# Name: history_segment, dtype: object

# %%
df.recency < 7 # True or False series
df[ df.recency < 7 ] # series with recency < 7 True 
df[ (df.recency < 7) & (df.newbie == 0) ]
# Out:
#        recency history_segment  history  mens  womens   zip_code  newbie  \
# 4            2    1) $0 - $100    45.34     1       0      Urban       0
# 5            6  2) $100 - $200   134.83     0       1  Surburban       0
# 13           2  2) $100 - $200   101.64     0       1      Urban       0
# 16           5    1) $0 - $100    29.99     1       0  Surburban       0
# 22           2  2) $100 - $200   118.40     1       0  Surburban       0
# 24           4    1) $0 - $100    78.24     1       0  Surburban       0
# 27           6  2) $100 - $200   162.98     0       1  Surburban       0
# 29           2  3) $200 - $350   203.35     1       0      Rural       0
# 30           2  3) $200 - $350   237.53     0       1  Surburban       0
# 32           6  2) $100 - $200   128.01     0       1      Urban       0
# 34           3    1) $0 - $100    29.99     1       0      Rural       0
# 35           4  3) $200 - $350   218.72     0       1      Urban       0
# ...

# %%
df[df.recency < 7] = -100
df
# Out:
#        recency   history_segment  history  mens  womens   zip_code  newbie  \
# 0           10    2) $100 - $200   142.44     1       0  Surburban       0
# 1         -100              -100  -100.00  -100    -100       -100    -100
# 2            7    2) $100 - $200   180.65     0       1  Surburban       1
# 3            9    5) $500 - $750   675.83     1       0      Rural       1
# 4         -100              -100  -100.00  -100    -100       -100    -100
# 5         -100              -100  -100.00  -100    -100       -100    -100
# 6            9    3) $200 - $350   280.20     1       0  Surburban       1
# 7            9      1) $0 - $100    46.42     0       1      Urban       0
# 8            9    5) $500 - $750   675.07     1       1      Rural       1
# 9           10      1) $0 - $100    32.84     0       1      Urban       1
# 10           7    5) $500 - $750   548.91     0       1      Urban       1
# ...
